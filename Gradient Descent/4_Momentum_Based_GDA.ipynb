# %% [markdown]
# Incorporates information from the previous weight updates to help the algorithm converge more quickly to the optimal solution. Momentum adds a term to the weight update that is proportional to the running average of the past gradients. The updates to the parameters are based on the current gradient and the previous updates. This can help prevent the optimization process from getting stuck in local minima and reach the global minimum faster.

# %% [markdown]
# Wt+1 = Wt - alpha * mt
#
# here instead of grad, we are using mt, what is it ?
#
# mt = Beta * mt-1 + (1-Beta) * Grad

# %%
import math
 
# HyperParameters of the optimization algorithm
alpha = 0.01
beta = 0.9
 
# Objective function
 
def obj_func(x):
    return x * x - 4 * x + 4
 
# Gradient of the objective functio
 
def grad(x):
    return 2 * x - 4
 
# Parameter of the objective function
x = 0
 
# Number of iterations
iterations = 0
 
v = 0
 
while (1):
    iterations += 1
    v = beta * v + (1 - beta) * grad(x)
 
    x_prev = x
 
    x = x - alpha * v
 
    print("Value of objective function on iteration", iterations, "is", x)
 
    if x_prev == x:
        print("Done optimizing the objective function. ")
        break
# Out:
# Value of objective function on iteration 1 is 0.003999999999999999
# Value of objective function on iteration 2 is 0.011591999999999998
# Value of objective function on iteration 3 is 0.022401615999999996
# Value of objective function on iteration 4 is 0.03608546716799999
# Value of objective function on iteration 5 is 0.05232876228486399
# Value of objective function on iteration 6 is 0.07084307036547186
# Value of objective function on iteration 7 is 0.09136426149728799
# Value of objective function on iteration 8 is 0.11365060499292794
# Value of objective function on iteration 9 is 0.13748101292901804
# Value of objective function on iteration 10 is 0.1626534180456411
# Value of objective function on iteration 11 is 0.18898327581451055
# Value of objective function on iteration 12 is 0.21630218125486403
# Value of objective function on iteration 13 is 0.24445659178867243
# Value of objective function on iteration 14 is 0.27330664808552263
# ...
